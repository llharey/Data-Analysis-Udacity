# %% [markdown]
# ### Virtual Analysis Report
#
# The Global_df was assessed and analysed. Th report on analysis and its foundings is reported below;

# %%
from IPython.display import Image
Image(filename='timeplot.png')

# %% [markdown]
# A decrease in total amount of followers was noticed across the years. This maybe one variable they might want to look at. As an increase in followers will mean a wider audience reach for them.

# %% [markdown]
# ### What stage of dog was more prominent

# %%
from IPython.display import Image
Image(filename='breedsplot.png')

# %% [markdown]
# During this analysis the none values were excluded as this will show a wrong anaysis in our plot
#
# From the plot above, pupper was the most common stage among dogs displayed on their twitter page.

# %% [markdown]
# ### What breed of dog is most likely to be in th top 3

# %%
from IPython.display import Image
Image(filename='breedplot.png')

# %% [markdown]
# from the above set of plots, we can say that labrador_retriever and golden retriever are very good looking dog breed as they are prominent in the amount of appearnce in the top 3

# %%
from IPython.display import Image
Image(filename='heatmapplot.png')

# %% [markdown]
# From the above heatmap, the following wa deduced;
#
# favorites and retweets have a strong positive correation, therefore the more pople retweet the tweet the more likes we are likely to get
#
# followers is negatively correlated to both favourites and retweets, although favourites has a more negative correlation than retweet
